# %% [markdown]
# #✅ Setup Inicial - Clonar o repositório

# %%
# ✅ Setup Inicial - Clonar o repositório
# !git clone https://github.com/LabShuHangGU/Adaptive-Token-Dictionary.git
# %cd Adaptive-Token-Dictionary
# Out:
# Cloning into 'Adaptive-Token-Dictionary'...
# remote: Enumerating objects: 133, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 133 (delta 12), reused 12 (delta 10), pack-reused 112 (from 2)
# Receiving objects: 100% (133/133), 12.68 MiB | 13.42 MiB/s, done.
# Resolving deltas: 100% (27/27), done.
# /content/Adaptive-Token-Dictionary

# %% [markdown]
# ## ✅ Instalar dependências (Google Colab já usa Python 3.9+)

# %%
# ✅ Instalar dependências (Google Colab já usa Python 3.9+)
# !pip install torch==2.0.1 torchvision==0.15.2
# !pip install -r requirements.txt
# !python setup.py develop
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 106.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 83.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 64.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 47.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 MB 12.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 MB 8.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.2/173.2 MB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.1/177.1 MB 6.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# # ✅ Baixar o modelo do Google Drive e imagem de teste

# %%
import gdown
import os

# Criação de diretórios se não existirem
os.makedirs("experiments/pretrained_models", exist_ok=True)
os.makedirs("input_images", exist_ok=True)

# Baixar modelo
gdown.download(id="1J9kR9OyrOxtJ5Ygbr_W116BLBwnD4VNL",
               output="experiments/pretrained_models/003_ATD_SRx4_finetune.pth",
               quiet=False)

# Baixar imagem
gdown.download(id="1B4Qafq44qYE1G838DW4TnjirIztFBEbb",
               output="input_images/teste.png",
               quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1J9kR9OyrOxtJ5Ygbr_W116BLBwnD4VNL
# From (redirected): https://drive.google.com/uc?id=1J9kR9OyrOxtJ5Ygbr_W116BLBwnD4VNL&confirm=t&uuid=1facd435-0624-477f-8754-9dc994d55627
# To: /content/Adaptive-Token-Dictionary/experiments/pretrained_models/003_ATD_SRx4_finetune.pth
# 100%|██████████| 164M/164M [00:00<00:00, 169MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1B4Qafq44qYE1G838DW4TnjirIztFBEbb
# To: /content/Adaptive-Token-Dictionary/input_images/teste.png
# 100%|██████████| 71.3k/71.3k [00:00<00:00, 59.5MB/s]
# 'input_images/teste.png'

# %% [markdown]
# # ✅ Executar inferência

# %%
# !python inference.py -i ./input_images/teste.png -o results/ --scale 4 --task classical
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
